# %%
import pandas as pd
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20100\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# # Анализ датасетов

# %%
data = pd.read_csv('train.csv', sep=',', encoding="ISO-8859-1")

# %%
data
# Out:
#            id  product_uid                                      product_title  \
# 0           2       100001                  Simpson Strong-Tie 12-Gauge Angle
# 1           3       100001                  Simpson Strong-Tie 12-Gauge Angle
# 2           9       100002  BEHR Premium Textured DeckOver 1-gal. #SC-141 ...
# 3          16       100005  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 4          17       100005  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# ...       ...          ...                                                ...
# 74062  221457       206638  Atlantic Windowpane 576 CD or 192 DVD Blu-Ray ...
# 74063  221458       206639  Philips 40-Watt Halogen R20 Flood Light Bulb (...
# 74064  221463       206641  Schlage Camelot In-Active Aged Bronze Handlese...
# 74065  221471       206648  Plastec 11 in. x 24 in. Rose Garden Wall Decor...
# 74066  221473       206650  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
#
#                                    search_term  relevance
# 0                                angle bracket       3.00
# 1                                    l bracket       2.50
# 2                                    deck over       3.00
# 3                             rain shower head       2.33
# 4                           shower only faucet       2.67
# ...                                        ...        ...
# 74062                           tv riser glass       1.00
# 74063                        r20 halogen light       3.00
# 74064  schlage lock siena half dummy knob with       2.33
# 74065                        zen garden  decor       3.00
# 74066             fine sheer curtain 63 inches       2.33
#
# [74067 rows x 5 columns]

# %%
data['id'].value_counts()
# Out:
# id
# 2         1
# 149832    1
# 149976    1
# 149974    1
# 149967    1
#          ..
# 75758     1
# 75757     1
# 75754     1
# 75748     1
# 221473    1
# Name: count, Length: 74067, dtype: int64

# %%
data_attribs = pd.read_csv('attributes.csv')

# %%
data_attribs
# Out:
#          product_uid                     name  \
# 0           100001.0                 Bullet01
# 1           100001.0                 Bullet02
# 2           100001.0                 Bullet03
# 3           100001.0                 Bullet04
# 4           100001.0                 Bullet05
# ...              ...                      ...
# 2044798     224428.0       Pilot Bit Included
# 2044799     224428.0  Power Tool Product Type
# 2044800     224428.0           Shank Diameter
# 2044801     224428.0              Shank Style
# 2044802     224428.0       Tools Product Type
#
#                                                      value
# 0        Versatile connector for various 90° connection...
# 1        Stronger than angled nailing or screw fastenin...
# 2        Help ensure joints are consistently straight a...
# 3                    Dimensions: 3 in. x 3 in. x 1-1/2 in.
# 4                                 Made from 12-Gauge steel
# ...                                                    ...
# 2044798                                                 No
# 2044799                                Drill & Router Bits
# 2044800                                             3/8 in
# 2044801                                                Hex
# 2044802                                         Power Tool
#
# [2044803 rows x 3 columns]

# %% [markdown]
# # Конкатенация датасетов

# %%
list_values = data_attribs.groupby('product_uid')['value'].apply(list)
list_names = data_attribs.groupby('product_uid')['name'].apply(list)

# %%
data_attribs.drop_duplicates('product_uid', inplace=True)

# %%
data_attribs['name'] = list_names

# %%
data_attribs.drop(labels=['name', 'value'], axis=1, inplace=True)
processed_data_attribs = data_attribs.join(list_names, on='product_uid')
processed_data_attribs = processed_data_attribs.join(list_values, on='product_uid')

# %%
processed_data_attribs
# Out:
#          product_uid                                               name  \
# 0           100001.0  [Bullet01, Bullet02, Bullet03, Bullet04, Bulle...
# 15          100002.0  [Application Method, Assembled Depth (in.), As...
# 50          100003.0  [Built-in flange, Bullet01, Bullet02, Bullet03...
# 82          100004.0  [Amperage (amps), Bullet01, Bullet02, Bullet03...
# 107         100005.0  [Bath Faucet Type, Built-in Water Filter, Bull...
# ...              ...                                                ...
# 2044680     224422.0  [Assembled Depth (in.), Assembled Height (in.)...
# 2044711     224423.0  [Bullet01, Bullet02, Bullet03, Bullet04, Bulle...
# 2044737     224424.0  [Assembly Required, Bullet01, Bullet02, Bullet...
# 2044755     224425.0  [Assembled Depth (in.), Assembled Height (in.)...
# 2044778     224428.0  [Arbor included, Bit Diameter, Bit Length (in....
#
#                                                      value
# 0        [Versatile connector for various 90° connectio...
# 15       [Brush,Roller,Spray, 6.63 in, 7.76 in, 6.63 in...
# 50       [Yes, Slightly narrower for tighter spaces, De...
# 82       [8.56, Positive power tolerance (0 to +5-Watt)...
# 107      [Combo Tub and Shower, No, Includes the trim k...
# ...                                                    ...
# 2044680  [0.44 in, 1.5 in, 0.44 in, 2 piece per pack, B...
# 2044711  [Adjusts to fit shower openings with a minimum...
# 2044737  [No, Solid wood construction, only the side an...
# 2044755  [49 in, 2 in, 20.5 in, Resists fading, stains ...
# 2044778  [No, 4 in, 1.6, Bi-Metal, Progressor tooth des...
#
# [86264 rows x 3 columns]

# %%
processed_data_attribs['product_uid'].isna().value_counts()
# Out:
# product_uid
# False    86263
# True         1
# Name: count, dtype: int64

# %%
processed_data_attribs[processed_data_attribs['product_uid'].isna()]
# Out:
#       product_uid name value
# 1929          NaN  NaN   NaN

# %%
processed_data_attribs.dropna(inplace=True)

# %%
processed_data_attribs['product_uid'] = processed_data_attribs['product_uid'].apply(int)

# %%
processed_data_attribs
# Out:
#          product_uid                                               name  \
# 0             100001  [Bullet01, Bullet02, Bullet03, Bullet04, Bulle...
# 15            100002  [Application Method, Assembled Depth (in.), As...
# 50            100003  [Built-in flange, Bullet01, Bullet02, Bullet03...
# 82            100004  [Amperage (amps), Bullet01, Bullet02, Bullet03...
# 107           100005  [Bath Faucet Type, Built-in Water Filter, Bull...
# ...              ...                                                ...
# 2044680       224422  [Assembled Depth (in.), Assembled Height (in.)...
# 2044711       224423  [Bullet01, Bullet02, Bullet03, Bullet04, Bulle...
# 2044737       224424  [Assembly Required, Bullet01, Bullet02, Bullet...
# 2044755       224425  [Assembled Depth (in.), Assembled Height (in.)...
# 2044778       224428  [Arbor included, Bit Diameter, Bit Length (in....
#
#                                                      value
# 0        [Versatile connector for various 90° connectio...
# 15       [Brush,Roller,Spray, 6.63 in, 7.76 in, 6.63 in...
# 50       [Yes, Slightly narrower for tighter spaces, De...
# 82       [8.56, Positive power tolerance (0 to +5-Watt)...
# 107      [Combo Tub and Shower, No, Includes the trim k...
# ...                                                    ...
# 2044680  [0.44 in, 1.5 in, 0.44 in, 2 piece per pack, B...
# 2044711  [Adjusts to fit shower openings with a minimum...
# 2044737  [No, Solid wood construction, only the side an...
# 2044755  [49 in, 2 in, 20.5 in, Resists fading, stains ...
# 2044778  [No, 4 in, 1.6, Bi-Metal, Progressor tooth des...
#
# [86263 rows x 3 columns]

# %%
full_data = data.merge(processed_data_attribs, on='product_uid', how='left')

# %%
full_data
# Out:
#            id  product_uid                                      product_title  \
# 0           2       100001                  Simpson Strong-Tie 12-Gauge Angle
# 1           3       100001                  Simpson Strong-Tie 12-Gauge Angle
# 2           9       100002  BEHR Premium Textured DeckOver 1-gal. #SC-141 ...
# 3          16       100005  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 4          17       100005  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# ...       ...          ...                                                ...
# 74062  221457       206638  Atlantic Windowpane 576 CD or 192 DVD Blu-Ray ...
# 74063  221458       206639  Philips 40-Watt Halogen R20 Flood Light Bulb (...
# 74064  221463       206641  Schlage Camelot In-Active Aged Bronze Handlese...
# 74065  221471       206648  Plastec 11 in. x 24 in. Rose Garden Wall Decor...
# 74066  221473       206650  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
#
#                                    search_term  relevance  \
# 0                                angle bracket       3.00
# 1                                    l bracket       2.50
# 2                                    deck over       3.00
# 3                             rain shower head       2.33
# 4                           shower only faucet       2.67
# ...                                        ...        ...
# 74062                           tv riser glass       1.00
# 74063                        r20 halogen light       3.00
# 74064  schlage lock siena half dummy knob with       2.33
# 74065                        zen garden  decor       3.00
# 74066             fine sheer curtain 63 inches       2.33
#
#                                                     name  \
# 0      [Bullet01, Bullet02, Bullet03, Bullet04, Bulle...
# 1      [Bullet01, Bullet02, Bullet03, Bullet04, Bulle...
# 2      [Application Method, Assembled Depth (in.), As...
# 3      [Bath Faucet Type, Built-in Water Filter, Bull...
# 4      [Bath Faucet Type, Built-in Water Filter, Bull...
# ...                                                  ...
# 74062  [Assembled Depth (in.), Assembled Height (in.)...
# 74063  [Actual Color Temperature (K), Average Life (h...
# 74064  [Application Type, Assembled Depth (in.), Asse...
# 74065  [Bullet01, Bullet02, Bullet03, Bullet04, Decor...
# 74066  [Assembled Depth (in.), Assembled Height (in.)...
#
#                                                    value
# 0      [Versatile connector for various 90° connectio...
# 1      [Versatile connector for various 90° connectio...
# 2      [Brush,Roller,Spray, 6.63 in, 7.76 in, 6.63 in...
# 3      [Combo Tub and Shower, No, Includes the trim k...
# 4      [Combo Tub and Shower, No, Includes the trim k...
# ...                                                  ...
# 74062  [9.5 in, 49 in, 32 in, Yes, Holds 216 Blu-rays...
# 74063  [2700, 2500, 2.5, Clear, Reflector, Flood and ...
# 74064  [Entry, 2.9 in, 12.9 in, 3 in, Adjustable, Use...
# 74065  [Indoor and outdoor use, Finished in Dark Bron...
# 74066  [.1 in, 63 in, 40 in, Sheer panel, gently filt...
#
# [74067 rows x 7 columns]

# %%
full_data.drop('id', axis=1, inplace=True)

# %%
full_data
# Out:
#        product_uid                                      product_title  \
# 0           100001                  Simpson Strong-Tie 12-Gauge Angle
# 1           100001                  Simpson Strong-Tie 12-Gauge Angle
# 2           100002  BEHR Premium Textured DeckOver 1-gal. #SC-141 ...
# 3           100005  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 4           100005  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# ...            ...                                                ...
# 74062       206638  Atlantic Windowpane 576 CD or 192 DVD Blu-Ray ...
# 74063       206639  Philips 40-Watt Halogen R20 Flood Light Bulb (...
# 74064       206641  Schlage Camelot In-Active Aged Bronze Handlese...
# 74065       206648  Plastec 11 in. x 24 in. Rose Garden Wall Decor...
# 74066       206650  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
#
#                                    search_term  relevance  \
# 0                                angle bracket       3.00
# 1                                    l bracket       2.50
# 2                                    deck over       3.00
# 3                             rain shower head       2.33
# 4                           shower only faucet       2.67
# ...                                        ...        ...
# 74062                           tv riser glass       1.00
# 74063                        r20 halogen light       3.00
# 74064  schlage lock siena half dummy knob with       2.33
# 74065                        zen garden  decor       3.00
# 74066             fine sheer curtain 63 inches       2.33
#
#                                                     name  \
# 0      [Bullet01, Bullet02, Bullet03, Bullet04, Bulle...
# 1      [Bullet01, Bullet02, Bullet03, Bullet04, Bulle...
# 2      [Application Method, Assembled Depth (in.), As...
# 3      [Bath Faucet Type, Built-in Water Filter, Bull...
# 4      [Bath Faucet Type, Built-in Water Filter, Bull...
# ...                                                  ...
# 74062  [Assembled Depth (in.), Assembled Height (in.)...
# 74063  [Actual Color Temperature (K), Average Life (h...
# 74064  [Application Type, Assembled Depth (in.), Asse...
# 74065  [Bullet01, Bullet02, Bullet03, Bullet04, Decor...
# 74066  [Assembled Depth (in.), Assembled Height (in.)...
#
#                                                    value
# 0      [Versatile connector for various 90° connectio...
# 1      [Versatile connector for various 90° connectio...
# 2      [Brush,Roller,Spray, 6.63 in, 7.76 in, 6.63 in...
# 3      [Combo Tub and Shower, No, Includes the trim k...
# 4      [Combo Tub and Shower, No, Includes the trim k...
# ...                                                  ...
# 74062  [9.5 in, 49 in, 32 in, Yes, Holds 216 Blu-rays...
# 74063  [2700, 2500, 2.5, Clear, Reflector, Flood and ...
# 74064  [Entry, 2.9 in, 12.9 in, 3 in, Adjustable, Use...
# 74065  [Indoor and outdoor use, Finished in Dark Bron...
# 74066  [.1 in, 63 in, 40 in, Sheer panel, gently filt...
#
# [74067 rows x 6 columns]

# %%
import matplotlib
full_data['search_term'].value_counts().hist()
# Out:
# <Axes: >

# %%
full_data['occurrences'] = full_data.groupby('search_term')['search_term'].transform('size')

# %%
full_data
# Out:
#        product_uid                                      product_title  \
# 0           100001                  Simpson Strong-Tie 12-Gauge Angle
# 1           100001                  Simpson Strong-Tie 12-Gauge Angle
# 2           100002  BEHR Premium Textured DeckOver 1-gal. #SC-141 ...
# 3           100005  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 4           100005  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# ...            ...                                                ...
# 74062       206638  Atlantic Windowpane 576 CD or 192 DVD Blu-Ray ...
# 74063       206639  Philips 40-Watt Halogen R20 Flood Light Bulb (...
# 74064       206641  Schlage Camelot In-Active Aged Bronze Handlese...
# 74065       206648  Plastec 11 in. x 24 in. Rose Garden Wall Decor...
# 74066       206650  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
#
#                                    search_term  relevance  \
# 0                                angle bracket       3.00
# 1                                    l bracket       2.50
# 2                                    deck over       3.00
# 3                             rain shower head       2.33
# 4                           shower only faucet       2.67
# ...                                        ...        ...
# 74062                           tv riser glass       1.00
# 74063                        r20 halogen light       3.00
# 74064  schlage lock siena half dummy knob with       2.33
# 74065                        zen garden  decor       3.00
# 74066             fine sheer curtain 63 inches       2.33
#
#                                                     name  \
# 0      [Bullet01, Bullet02, Bullet03, Bullet04, Bulle...
# 1      [Bullet01, Bullet02, Bullet03, Bullet04, Bulle...
# 2      [Application Method, Assembled Depth (in.), As...
# 3      [Bath Faucet Type, Built-in Water Filter, Bull...
# 4      [Bath Faucet Type, Built-in Water Filter, Bull...
# ...                                                  ...
# 74062  [Assembled Depth (in.), Assembled Height (in.)...
# 74063  [Actual Color Temperature (K), Average Life (h...
# 74064  [Application Type, Assembled Depth (in.), Asse...
# 74065  [Bullet01, Bullet02, Bullet03, Bullet04, Decor...
# 74066  [Assembled Depth (in.), Assembled Height (in.)...
#
#                                                    value  occurrences
# 0      [Versatile connector for various 90° connectio...           11
# 1      [Versatile connector for various 90° connectio...            7
# 2      [Brush,Roller,Spray, 6.63 in, 7.76 in, 6.63 in...            8
# 3      [Combo Tub and Shower, No, Includes the trim k...            8
# 4      [Combo Tub and Shower, No, Includes the trim k...           10
# ...                                                  ...          ...
# 74062  [9.5 in, 49 in, 32 in, Yes, Holds 216 Blu-rays...           10
# 74063  [2700, 2500, 2.5, Clear, Reflector, Flood and ...            2
# 74064  [Entry, 2.9 in, 12.9 in, 3 in, Adjustable, Use...            3
# 74065  [Indoor and outdoor use, Finished in Dark Bron...           11
# 74066  [.1 in, 63 in, 40 in, Sheer panel, gently filt...           10
#
# [74067 rows x 7 columns]

# %%
full_data['occurrences'].value_counts()
# Out:
# occurrences
# 9     10827
# 8     10544
# 10     9830
# 7      8736
# 11     6721
# 6      6228
# 5      4340
# 12     4284
# 4      2780
# 3      2511
# 13     2483
# 2      1886
# 1      1399
# 14      994
# 15      360
# 16      144
# Name: count, dtype: int64

# %%
import matplotlib
full_data['search_term'].value_counts().hist()
# Out:
# <Axes: >

# %%
full_data.to_csv('full_data.csv')
